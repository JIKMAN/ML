# %% [markdown]
# > ### 머신러닝 sklearn code

# %%
# %pip install matplotlib

mport matplotlib.pyplot as plt

# train, test 데이터셋 만들기
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=5)

# 단일, 다중선형회귀
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

#로지스틱 회귀
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression(solver='saga', max_iter=7500)

model.coef_ # 세타0를 제외한 세타값들
model.intercept_ #세타0 값 = 상수항
# 평균 제곱 오차의 루트를 통해서 테스트 데이터에서의 모델 성능 판단
mse = mean_squared_error(y_test, y_test_predict)


#전처리
from sklearn import preprocessing
# 다항 만들기
from sklearn.preprocessing import PolynomialFeatures
polynomial_transformer = PolynomialFeatures(4)  # 4 차항 변형기를 정의
polynomial_features = polynomial_transformer.fit_transform(X.values)  #  4차 항 변수로 변환
features = polynomial_transformer.get_feature_names(X.columns) #     
# Normalization 과정
scaler = preprocessing.MinMaxScaler() 
normalized_df = scaler.fit_transform(df)
pd.DataFrame(normalized_df, columns=df.columns) # 기존 데이터를 Normalize 시킨 새로운 데이터프레임

# One-hot encoding
X = pd.get_dummies(input_data)

# Regularization 과정
scaler = preprocessing.StandardScaler()
standardized_data = scaler.fit_transform(height_weight_age_df)

# L1 정규화
from sklearn.linear_model import Lasso
model = Lasso(alpha=0.001, max_iter=2000, normalize=True)
model.fit(X_train, y_train)
# L2 정규화
from sklearn.linear_model import Ridge
model = Ridge(alpha=0.01, max_iter=2000, normalize=True)
model.fit(X_train, y_train)

#로지스틱 회귀는 기본적으로 L2 정규화를 이용한다.
LogisticRegression(penalty='none')  # 정규화 사용 안함
LogisticRegression(penalty='l1')  # L1 정규화 사용
LogisticRegression(penalty='l2')  # L2 정규화 사용
LogisticRegression()  # 위와 똑같음: L2 정규화 사용


# K겹 교차검증(로지스틱 회귀에 적용하는 예시)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
logistic_model = LogisticRegression(solver='saga', max_iter=2000)
k_fold_score = np.average(cross_val_score(logistic_model, X, y, cv=5)) # 교차 검증한 값들의 평균 성능

# 그리드 서치(알파값과 iter 값을 여러가지 경우의 수로 나눠서 실행)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
logistic_model = LogisticRegression()
hyper_parameters = {
    'penalty': ['l1', 'l2'],
    'max_iter': [500, 1000, 1500, 2000]
}
hyper_parameter_tuner = GridSearchCV(estimator=logistic_model, param_grid=hyper_parameters, cv=5) # cv : 몇겹 교차검증 인지
hyper_parameter_tuner.fit(X, y)
best_params = hyper_parameter_tuner.best_params_ # 가장 성능이 좋은 경우 출력


# 결정트리
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier #랜덤포래스트(배깅+결정트리)
model = RandomForestClassifier(n_estimators=10, max_depth=4, random_state=42)
model.fit(X_train, y_train)
from sklearn.ensemble import AdaBoostClassifier # 아다부스트(틀린 값들의 속성중요도를 높이는 방법)
model = AdaBoostClassifier(n_estimators=50, random_state=5)
model.fit(X_train, y_train)

model.feature_importances_ # 속성중요도
np.argsort(importances) #속성중요도 순위 나열
